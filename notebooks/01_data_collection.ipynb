# %% [markdown]
# # Data Collection Pipeline - Cryptocurrency Flash Crash Predictor
#
# This notebook illustrates and initiates connection parameters to pull live trades and order events using the Binance WebSocket public API stream.

# %%
from src.data.binance_collector import BinanceDataCollector

# Instantiate and start a short collector run
collector = BinanceDataCollector(symbol='BTCUSDT', output_path='../data/raw/')
print("Collector loaded. Ready to execute stream collection.")
